# %%
import numpy as np
import pandas as pd

# %%
main_data = pd.read_table("data-with-cast.tsv")

# %%
ratings_data = pd.read_table("ratings-data.tsv",usecols=["tconst","averageRating"])

# %%
mdata = pd.merge(main_data,ratings_data,on="tconst")
mdata
# Out:
#        Unnamed: 0     tconst titleType                  primaryTitle  \
# 0               0  tt0032557  tvSeries              The Green Archer
# 1               1  tt0035803  tvSeries      The German Weekly Review
# 2               3  tt0039120  tvSeries                     Americana
# 3               6  tt0039123  tvSeries                 Kraft Theatre
# 4               7  tt0039125  tvSeries             Public Prosecutor
# ...           ...        ...       ...                           ...
# 70974      166768  tt9915338  tvSeries  Aunty Donna: Camp Bush Camp!
# 70975      166769  tt9915686  tvSeries               The Khatra Show
# 70976      166771  tt9915822  tvSeries            Ichhapyaari Naagin
# 70977      166774  tt9916206  tvSeries                         Nojor
# 70978      166777  tt9916380  tvSeries           Meie aasta Aafrikas
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# ...

# %%
mdata.to_csv("final-data.tsv",sep="\t")
