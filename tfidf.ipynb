# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('final-dataset.csv')

# %%
df
# Out:
#                           title                   genre  rating  \
# 0              The Green Archer  Action,Adventure,Crime     6.6
# 1      The German Weekly Review        Documentary,News     7.7
# 2                     Americana        Family,Game-Show     3.0
# 3                 Kraft Theatre                   Drama     8.4
# 4                Actor's Studio                   Drama     7.1
# ...                         ...                     ...     ...
# 30838         Indecent Proposal            Reality,2015     4.0
# 30839           Marine Machines        Documentary,2005     5.4
# 30840      Deep Wreck Mysteries        Documentary,2009     6.4
# 30841              State Parole        2008,Prime Video     4.6
# 30842             Rainbow Horse        Animation,Family     4.6
#
#                                              description
# 0      Columbia's 12th serial of 57 total (following ...
# 1      News of the Week: German Troops Capture Rome; ...
# 2      Americana is a weekly game show which ran on N...
# 3      Kraft Television Theatre is an American drama/...
# 4      Actors Studio is an American TV show which air...
# ...                                                  ...
# 30838  Stories of everyday individuals are featured, ...
# 30839  Marine Machines has one or more episodes strea...
# 30840  Britain and Ireland, island nations, have the ...
# 30841  State Parole has one or more episodes streamin...
# 30842  With "Rainbow Horse," families can saddle up a...
#
# [30843 rows x 4 columns]

# %%
df2 = df.iloc[0:20000,:]

# %%
df2
# Out:
#                                         title                       genre  \
# 0                            The Green Archer      Action,Adventure,Crime
# 1                    The German Weekly Review            Documentary,News
# 2                                   Americana            Family,Game-Show
# 3                               Kraft Theatre                       Drama
# 4                              Actor's Studio                       Drama
# ...                                       ...                         ...
# 19995     The File of Young Kindaichi Returns           Animation,Mystery
# 19996  Fate/stay night: Unlimited Blade Works    Action,Animation,Fantasy
# 19997                       Mästarnas mästare  Game-Show,Reality-TV,Sport
# 19998            Smartare än en femteklassare                   Game-Show
# 19999             House of Horrors: Kidnapped           Crime,Documentary
#
#        rating                                        description
# 0         6.6  Columbia's 12th serial of 57 total (following ...
# 1         7.7  News of the Week: German Troops Capture Rome; ...
# 2         3.0  Americana is a weekly game show which ran on N...
# 3         8.4  Kraft Television Theatre is an American drama/...
# 4         7.1  Actors Studio is an American TV show which air...
# ...       ...                                                ...
# 19995     7.5  High school student Hajime Kindaichi is the su...
# 19996     8.0  The Holy Grail War is a battle royale among se...
# 19997     7.9  A Swedish sport competition based on "Eeuwige ...
# 19998     5.4  A Swedish game show based on "Are You Smarter ...
# 19999     8.1  HOUSE OF HORRORS: KIDNAPPED tells the gripping...
#
# [20000 rows x 4 columns]

# %%
tfidf = TfidfVectorizer(min_df=3,max_features=None,strip_accents='unicode',analyzer='word',token_pattern=r'\w{1,}',ngram_range=(1,3),stop_words='english')
df2['description'] = df2['description'].fillna('')
tfidf_matrix = tfidf.fit_transform(df2['description'])
# Out:
# <ipython-input-8-498c85eed135>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['description'] = df2['description'].fillna('')

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.        , 0.0052648 , ..., 0.        , 0.        ,
#         0.00816511],
#        [0.        , 1.        , 0.01346079, ..., 0.        , 0.        ,
#         0.        ],
#        [0.0052648 , 0.01346079, 1.        , ..., 0.        , 0.01274671,
#         0.00171559],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.11669323,
#         0.        ],
#        [0.        , 0.        , 0.01274671, ..., 0.11669323, 1.        ,
#         0.        ],
#        [0.00816511, 0.        , 0.00171559, ..., 0.        , 0.        ,
#         1.        ]])
